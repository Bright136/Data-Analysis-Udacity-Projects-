# %%
import pandas as pd
import numpy as mp
# %matplotlib inline 
import matplotlib.pyplot as plt
import time

# %%
df = pd.read_csv("tmdb-movies.csv")

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10861    False
# 10862    False
# 10863    False
# 10864    False
# 10865    False
# Length: 10866, dtype: bool

# %%
df = df.drop_duplicates()
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# homepage                7929
# tagline                 2824
# keywords                1493
# production_companies    1030
# cast                      76
# director                  44
# genres                    23
# imdb_id                   10
# overview                   4
# budget_adj                 0
# release_year               0
# vote_average               0
# vote_count                 0
# release_date               0
# id                         0
# runtime                    0
# original_title             0
# revenue                    0
# budget                     0
# popularity                 0
# revenue_adj                0
# dtype: int64

# %%
df = df.drop(["homepage", "tagline", "keywords", "production_companies", "id", "imdb_id"], axis=1)
df.head()
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# ...

# %%
df.isnull().sum()
# Out:
# popularity         0
# budget             0
# revenue            0
# original_title     0
# cast              76
# director          44
# overview           4
# runtime            0
# genres            23
# release_date       0
# vote_count         0
# vote_average       0
# release_year       0
# budget_adj         0
# revenue_adj        0
# dtype: int64

# %%
df.sort_values(by="release_year", ascending=False)
# Out:
#        popularity     budget     revenue      original_title  \
# 0       32.985763  150000000  1513528810      Jurassic World
# 423      0.244950          0           0      7 Days in Hell
# 416      0.248964          0           0               Curve
# 417      0.248280    7500000           0      Pound of Flesh
# 418      0.247595          0           0          Cyberbully
# ...           ...        ...         ...                 ...
# 10166    0.136525          0           0  Carry On Constable
# 10165    0.138777          0           0        Elmer Gantry
# 10164    0.144106          0           0      The Lost World
# 10163    0.162753          0           0    Inherit the Wind
# 10162    0.194948          0           0  Sink the Bismarck!
#
#                                                     cast         director  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 423    Andy Samberg|Kit Harington|Jon Hamm|Michael Sh...   Jake Szymanski
# ...

# %%
movies_df = df[df["budget"] != 0]
movies_df = df[df["revenue"] != 0]
movies_df
# Out:
#        popularity     budget     revenue                   original_title  \
# 0       32.985763  150000000  1513528810                   Jurassic World
# 1       28.419936  150000000   378436354               Mad Max: Fury Road
# 2       13.112507  110000000   295238201                        Insurgent
# 3       11.173104  200000000  2068178225     Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                        Furious 7
# ...           ...        ...         ...                              ...
# 10822    0.670274    7500000    33736689  Who's Afraid of Virginia Woolf?
# 10828    0.402730    3000000    13000000                     Torn Curtain
# 10829    0.395668    4653000     6000000                        El Dorado
# 10835    0.299911   12000000    20000000                 The Sand Pebbles
# 10848    0.207257    5115000    12000000                 Fantastic Voyage
#
#                                                     cast           director  \
# ...

# %%
movies_df["revenue"] = movies_df["revenue"] / 1000000
movies_df["budget"] = movies_df["budget"] / 1000000
# Out:
# <ipython-input-115-1e03092d3482>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df["revenue"] = movies_df["revenue"] / 1000000
# <ipython-input-115-1e03092d3482>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df["budget"] = movies_df["budget"] / 1000000

# %%
movies_df["profit"] = movies_df["revenue"] - movies_df["budget"]
movies_df
# Out:
# <ipython-input-116-a1048bc08edf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df["profit"] = movies_df["revenue"] - movies_df["budget"]
#        popularity   budget   revenue                   original_title  \
# 0       32.985763  150.000  0.000150                   Jurassic World
# 1       28.419936  150.000  0.000150               Mad Max: Fury Road
# 2       13.112507  110.000  0.000110                        Insurgent
# 3       11.173104  200.000  0.000200     Star Wars: The Force Awakens
# 4        9.335014  190.000  0.000190                        Furious 7
# ...           ...      ...       ...                              ...
# 10822    0.670274    7.500  0.000008  Who's Afraid of Virginia Woolf?
# ...

# %%
top_10_profits = movies_df.head(10)
top_10_profits
# Out:
#    popularity  budget   revenue                original_title  \
# 0   32.985763   150.0  0.000150                Jurassic World
# 1   28.419936   150.0  0.000150            Mad Max: Fury Road
# 2   13.112507   110.0  0.000110                     Insurgent
# 3   11.173104   200.0  0.000200  Star Wars: The Force Awakens
# 4    9.335014   190.0  0.000190                     Furious 7
# 5    9.110700   135.0  0.000135                  The Revenant
# 6    8.654359   155.0  0.000155            Terminator Genisys
# 7    7.667400   108.0  0.000108                   The Martian
# 8    7.404165    74.0  0.000074                       Minions
# 9    6.326804   175.0  0.000175                    Inside Out
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# ...
